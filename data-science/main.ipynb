# %%
# importing libraries
from cv2 import dnn_superres, imread, imwrite, resize
from json import dump, load
import pytesseract
from os import listdir, rename, system
from pathlib import Path

# %%
# Super resolution setup
sr = dnn_superres.DnnSuperResImpl_create()
sr.readModel("FSRCNN_x4.pb")
sr.setModel("fsrcnn", 4)
# Out:
# Upscaled ZHHl7pp.png to 8kk

# %%
# Download images
for text in listdir('./docs/urls/'):
    with open(f'./docs/urls/{text}') as file:
        folder = text.replace('.txt', '')
        for code in map(str.strip, file):
            url = f"https://i.imgur.com/{code}.png"
            system(f'curl -L "{url}" -o "./img/{folder}/{code}.png"')

# %%
# Upscale images
for folder in listdir('./img/'):
    for image in listdir(f'./img/{folder}'):
        if image.endswith('.jpg'):
            rename(f'./img/{folder}/{image}', f'./img/{folder}/{image[:-4]}.png')
        img = imread(f'./img/{folder}/{image}')
        result = resize(sr.upsample(img), (4320, 7111))
        imwrite(f"./upscaled/{image}", result)

# %%
# OCR descriptions
with open('./cards.json') as file:
    data = load(file)
for card in data:
    card.setdefault('strength', '')
    image = imread(f'./upscaled/{card["filename"]}.png')
    card['description'] = pytesseract.image_to_string(image, lang='eng')
with open('./cards.json', 'w') as file:
    dump(data, file, indent=4)

# %%
# Update url txt files
for text in listdir('./docs/urls/'):
    folder = text.replace('.txt', '')
    with open(f'./docs/urls/{text}', 'w') as file:
        file.writelines(f"{img.replace('.png','')}\n" for img in listdir(f'./img/{folder}'))
# Out:
# Added 05ZwvFV to data
# Added 07hvr0c to data
# Added 0f4y9Er to data
# Added 0hZKbQt to data
# Added 0mhpv7J to data
# Added 0NxOHvK to data
# Added 0PtkWhi to data
# Added 0QCRTyN to data
# Added 0r8rJ9V to data
# Added 0SfrfoB to data
# Added 0sYrnzt to data
# Added 0T06Hez to data
# Added 0tnv82D to data
# Added 0u5HZpT to data
# Added 0UDloUz to data
# Added 0VQ1SeK to data
# Added 0ZJv0sl to data
# Added 11jCfZg to data
# Added 13Df1TQ to data
# Added 18lXfcL to data
# Added 19UVfJj to data
# Added 1a9llyn to data
# Added 1AKYGlX to data
# Added 1HmmkKw to data
# Added 1i1ZfxU to data
# Added 1j0DEEa to data
# Added 1jFTzff to data
# Added 1JVAgGB to data
# Added 1jyBEr7 to data
# Added 1KYTVlX to data
# Added 1lgizEY to data
# Added 1mEs5uP to data
# Added 1O2vtTb to data
# Added 1oJxrGw to data
# Added 1Ow9Ixi to data
# Added 1rpoqSt to data
# Added 1Rwikhw to data
# Added 1Scpa2z to data
# Added 1vctdYt to data
# Added 1wkaC9F to data
# Added 1YrEApq to data
# Added 21CakIc to data
# Added 22iqLFj to data
# Added 22pNNuz to data
# Added 24OiOJV to data
# Added 26OqtaT to data
# Added 2B0RdIU to data
# Added 2dqqGKj to data
# Added 2E6Ku2w to data
# Added 2f17D2W to data
# Added 2I3PEuV to data
# Added 2JX9VRX to data
# Added 2mCcxUt to data
# Added 2mROSUV to data
# Added 2pmorhd to data
# Added 2QVAbrb to data
# Added 2v2Zn0E to data
# Added 2VCvawP to data
# Added 2VmIXfi to data
# Added 2VYJ2gw to data
# Added 2xPmFGv to data
# Added 38LcGbA to data
# Added 38Ql1Mv to data
# Added 3aiYU5X to data
# Added 3b9OfPF to data
# Added 3bB6o7h to data
# Added 3CdAfNF to data
# Added 3G9iWar to data
# Added 3hJ7kkK to data
# Added 3HjTk8n to data
# Added 3IfZUhX to data
# Added 3JtLIbW to data
# Added 3nsbsBw to data
# Added 3O0BE5Y to data
# Added 3qEX2rq to data
# Added 3Qk7M1q to data
# Added 3uN46Up to data
# Added 3UqSmAJ to data
# Added 3Y5poMg to data
# Added 3ypFsHZ.jpg to data
# Added 42JEWHC to data
# Added 43eu0fm to data
# Added 45dxVJp to data
# Added 48VynQV to data
# Added 4DuvI3t to data
# Added 4EQxZ4Z to data
# Added 4eTqBqp to data
# Added 4ji0mGt to data
# Added 4KCD1oS to data
# Added 4KpoNbO to data
# Added 4lX6bKm to data
# Added 4nIaN4A to data
# Added 4nqJGM8 to data
# Added 4o5qJ9K to data
# Added 4pgFm85 to data
# Added 4QS1zdD to data
# Added 4Ui2P0S to data
# Added 4v2MW32 to data
# Added 4vq7IPq to data
# Added 5ArAOj3 to data
# Added 5cuCmsG to data
# Added 5gfT0ls to data
# Added 5IUgv6q to data
# Added 5Lcr2WB to data
# Added 5mDuCOg to data
# Added 5PIAGZq to data
# Added 5Q6GzGw to data
# Added 5RIydlW to data
# Added 5VNQKzl to data
# Added 5vWNEWS to data
# Added 5wCJOMM to data
# Added 5XU2JWH to data
# Added 5Y1WBXP to data
# Added 622d14E to data
# Added 62coCXt to data
# Added 62MFLC2 to data
# Added 66lHqap to data
# Added 66WeTKA to data
# Added 672DAxC to data
# Added 67muOXU to data
# Added 68AX4ew to data
# Added 68mUpGE to data
# Added 6A4KKXG to data
# Added 6A6M9z4 to data
# Added 6B79f0W to data
# Added 6boAyDw to data
# Added 6cO7X2N to data
# Added 6cZGhpF to data
# Added 6feGLCt to data
# Added 6Fehaie to data
# Added 6FUlMzH to data
# Added 6iT40Kh to data
# Added 6Lz9NrQ to data
# Added 6QEfMkH to data
# Added 6tfZbrD to data
# Added 6tHIWbD to data
# Added 6UQ5NZo to data
# Added 6vCQrPB to data
# Added 724cc2d to data
# Added 72gGuUh to data
# Added 75GlBBB to data
# Added 7G8n5bL to data
# Added 7Gj95M2 to data
# Added 7H72rdt to data
# Added 7HtnFHh to data
# Added 7puReva to data
# Added 7VVetdx to data
# Added 82zDnad to data
# Added 84C0f5i to data
# Added 8arQ4ov to data
# Added 8B2w4WR to data
# Added 8fCOkoo to data
# Added 8HKxjiN to data
# Added 8IZ9dv7 to data
# Added 8jts6Wq to data
# Added 8L2qP7J.jpg to data
# Added 8lQBvQl to data
# Added 8LZyNQ6 to data
# Added 8O0NnAG to data
# Added 8tjzcp4 to data
# Added 8U7PwPP to data
# Added 8vcUmzV to data
# Added 8Vp9Wzd to data
# Added 8xl5XFL to data
# Added 8zVn4Ij to data
# Added 93mflou to data
# Added 9aMG4A1 to data
# Added 9boG0To to data
# Added 9cQWhIx to data
# Added 9d9Rg05 to data
# Added 9EQQKbH to data
# Added 9F6Fbbw to data
# Added 9FC6jbC to data
# Added 9GGwBaH to data
# Added 9gJAnD8 to data
# Added 9HT0sEn to data
# Added 9JEhpeA to data
# Added 9k5LGC9 to data
# Added 9KvxXvI to data
# Added 9LxVldT to data
# Added 9nSUSR3 to data
# Added 9qaA8LF to data
# Added 9rJrcRN to data
# Added 9SZviEf to data
# Added 9t95TdB to data
# Added 9uFrUU4 to data
# Added 9UVPNte to data
# Added 9WcQwrw to data
# Added 9yKRaGQ to data
# Added 9Yu4zWz to data
# Added a0obp4G to data
# Added a1nAVs6 to data
# Added a2VYF22 to data
# Added a3aG5ID to data
# Added A3ZC0Rw to data
# Added a4sd0vc to data
# Added A8MyBkY to data
# Added a9gCGkA to data
# Added A9uNfaD to data
# Added aa7ihl1 to data
# Added aCSi5Fo to data
# Added ADI4XRj to data
# Added ADNRug7 to data
# Added Adwr0b9 to data
# Added aEAXtmY to data
# Added aeJj8gw to data
# Added aFGMjQA to data
# Added ags31F5 to data
# Added aHlerUt to data
# Added Ahm4rv1 to data
# Added AI3UMj8 to data
# Added aJgBnRM to data
# Added AJOaa9I to data
# Added AL7O5WK to data
# Added ALN2RpC to data
# Added alsvior to data
# Added AMXErOT to data
# Added ANtcNCy to data
# Added aQ62KqP to data
# Added AQYTZRC to data
# Added arfi1hD to data
# Added AsdI0pK to data
# Added ASZFBR6 to data
# Added ATaWJAF to data
# Added ATqrcJf to data
# Added Atyjn1D to data
# Added aU4NLWc to data
# Added aVVkIgt to data
# Added AwYWmal to data
# Added axnTeXe to data
# Added Axv8adJ to data
# Added AxxTrwS to data
# Added aY1954O to data
# Added b1BIBjR to data
# Added b3e7aZz to data
# Added b3fqCze to data
# Added B73QlAF to data
# Added B74Peyg to data
# Added b9BBwFj to data
# Added B9PkNKS to data
# Added Balwp1J to data
# Added BdZqCpo to data
# Added bg5izlU to data
# Added bJ20SdT to data
# Added bjbWKMO to data
# Added BJxoZsa to data
# Added BlcCYkY to data
# Added BLfFx0F to data
# Added bluEqAB to data
# Added blZxE4J to data
# Added Bml84Bt to data
# Added bmwh6k9 to data
# Added BNqtul9 to data
# Added BPUjGOI to data
# Added BQPBkZM to data
# Added bUGZtpy to data
# Added BunXlJK to data
# Added ByuIMVP to data
# Added bZPvvwY to data
# Added C09DzG8 to data
# Added c09LmP0 to data
# Added C26JtEI to data
# Added c3JuK7n to data
# Added c3qd1tm to data
# Added c4PrKQt to data
# Added c5m2k5z to data
# Added c7azISA to data
# Added CaoPX3k to data
# Added cBUflif to data
# Added CBzBCAR to data
# Added CCyLmPK.jpg to data
# Added cdGBhSn to data
# Added ceNiEP2 to data
# Added Cf3m8bc to data
# Added cGVLzWt to data
# Added chPrIhk to data
# Added CiXILar to data
# Added ck0vxhE to data
# Added cNIXg2J to data
# Added cOLU5Qj to data
# Added CplJeva to data
# Added CpWbMho to data
# Added cPWjsJv to data
# Added Cr0ioCc to data
# Added cRspMBh to data
# Added cRVjaFV to data
# Added CsGCFGY to data
# Added CtIuS9r to data
# Added cV6ATMZ to data
# Added cvgQWmm to data
# Added cwyi781 to data
# Added cxCaE1d to data
# Added cxyum9U to data
# Added Cydtecq to data
# Added cYK7AKM to data
# Added CzjiQDf to data
# Added cZWmRQa to data
# Added D0Q7CQt to data
# Added d26m8Ed to data
# Added D6FmBcY to data
# Added d6XXwOi to data
# Added DAVll4J to data
# Added DbjAxQL to data
# Added DdFsVtQ to data
# Added dEjP11t to data
# Added DfnScah to data
# Added DjbRRe1 to data
# Added DKo7icV to data
# Added dM6u6ag to data
# Added DmONYhO to data
# Added DnNTjO7 to data
# Added dpd05Si to data
# Added dPRQw7F to data
# Added DqHrE50 to data
# Added dttzZTh to data
# Added dvHbt03 to data
# Added dVol0Ae to data
# Added DWwfjHR to data
# Added dY13sXh to data
# Added DYA9uE9 to data
# Added dzMN4De to data
# Added dZzh7kB to data
# Added E01WBpf to data
# Added e2yksyG to data
# Added E46hJbx to data
# Added e5qqjeF to data
# Added e5sI1tq to data
# Added E6xt53l to data
# Added e8YYAlR.jpg to data
# Added ea3Vadm to data
# Added ebj7eui to data
# Added eBQiCIK to data
# Added edMTPXq to data
# Added EDulO4g to data
# Added eE4Nanq to data
# Added eeMLQla to data
# Added eEXEq6T to data
# Added eGgiJ3M to data
# Added EGsJHqe to data
# Added ehEe4o8 to data
# Added eHR63Uz to data
# Added EhZG2Ne to data
# Added EIe5cgM to data
# Added EizPY3g to data
# Added Ej3sXLw to data
# Added eJWAwbx to data
# Added EK9iCSc to data
# Added EKoOwaz to data
# Added EKr7NQh to data
# Added eLI9POD to data
# Added ELjZhrt to data
# Added EmTCbQ5 to data
# Added en6Ey3X to data
# Added EnbnTTf to data
# Added eoc5QOT to data
# Added eoQenmg to data
# Added eor6uQW to data
# Added eqj6S42.jpg to data
# Added ErNrmsq to data
# Added ERZFjTg to data
# Added EsJDQOu to data
# Added eSNcEHw to data
# Added eVPRJyf to data
# Added EW1nzio to data
# Added eXEPbJT to data
# Added eY3nEUL to data
# Added ey8Wn6x to data
# Added eyjbPsZ to data
# Added eYkRMAF to data
# Added f0QGxxN to data
# Added F0s5SGi to data
# Added F2FvURV to data
# Added f4UQI6C to data
# Added F6bkBnr to data
# Added F78dJIR to data
# Added f8XSNF8 to data
# Added f9fIUwO to data
# Added f9IIay2 to data
# Added FAa89DA to data
# Added fawRSGY.jpg to data
# Added FBeqEKW to data
# Added Fcfeg1l to data
# Added fcZFvTQ to data
# Added fDWJUSK to data
# Added fDyrFf7 to data
# Added FE8LMXy to data
# Added FeVmQYJ to data
# Added FezYaQp to data
# Added ffqUvpR to data
# Added FhkEz2P to data
# Added FIuXBnQ to data
# Added fJ8Ys0q to data
# Added FjzS8IG to data
# Added FK0WKrn to data
# Added FLkdU51 to data
# Added flqnqBk to data
# Added fMBJEpC to data
# Added fofnfYk to data
# Added fqJN40m to data
# Added FQtOm3O.jpg to data
# Added FT8U9Yh to data
# Added ftjZfed to data
# Added fv9WxGX to data
# Added fVxDWwx to data
# Added FW9Tzwz to data
# Added FWi5Mtz to data
# Added FWJbLiZ to data
# Added fxhqKpu to data
# Added FxpGw69 to data
# Added fxtcIWA to data
# Added FYQv2Uw to data
# Added fz6pZNM to data
# Added G3kEa6j to data
# Added G6i8Pww to data
# Added g7pwKIz to data
# Added g9OEW8x to data
# Added gBsjZ15 to data
# Added GCA5fKy to data
# Added geWX42U to data
# Added GfMplvT to data
# Added ggGJLcq to data
# Added gGGRuQS to data
# Added ghesJL8 to data
# Added GhRbPGF to data
# Added GiDSLCu to data
# Added gikCitB to data
# Added gJZLP0j to data
# Added GKWn4Uy to data
# Added GlHeIJ3 to data
# Added GmZ3PBg to data
# Added Gon4t48 to data
# Added GorqVRQ to data
# Added gp5v23l to data
# Added gPi0Dlq to data
# Added GRJUvlD to data
# Added GV7p8JL to data
# Added GVwNSjY to data
# Added GXCfKWZ to data
# Added GxVhKey to data
# Added gYsVJE3 to data
# Added gyyEcTn to data
# Added GZPACza to data
# Added H01RzUZ to data
# Added H0YkUnU to data
# Added H1ALU7u to data
# Added H3UMreR to data
# Added h48Wd07 to data
# Added H4AQZ8A to data
# Added h4ZgsTi to data
# Added H5MJ1iN to data
# Added h5vB1rM to data
# Added H69Twok to data
# Added h8oYNLf to data
# Added hahDUMW to data
# Added hbQ4e5d to data
# Added hbZ4aPp to data
# Added hdLNF3F to data
# Added HdlQ78j to data
# Added hdXfjcR to data
# Added HfhkgTw to data
# Added HFRyrXS to data
# Added hgekFy2 to data
# Added himpOWP to data
# Added hJCxQOa to data
# Added HkYR93U to data
# Added hlskLWL to data
# Added hnaI3SB to data
# Added HnCXgmS to data
# Added hNTK21t to data
# Added Ho4wt2h to data
# Added ho7Ym5g to data
# Added HOSHHQd to data
# Added hpuH4bD to data
# Added hQdHK5r to data
# Added HRMxfug to data
# Added HRzmHUD to data
# Added HsDDHbo to data
# Added HugSnJ4 to data
# Added huLWyVN to data
# Added hWbcSVB to data
# Added hWiITRa to data
# Added HwmvR3B to data
# Added hXLWzGN to data
# Added hxNjKRU to data
# Added hY9NJp1 to data
# Added hzxLb1F to data
# Added I01TILY to data
# Added I1Z1Lhs to data
# Added i2l9SZ6 to data
# Added I2W7oi4 to data
# Added i59SSQg to data
# Added I59W7od to data
# Added I5NfBVw to data
# Added I5TWdcR to data
# Added IA6de7V to data
# Added IBLGHoC to data
# Added IBVDHez to data
# Added Ic1akjI to data
# Added IcOTTSk to data
# Added ICZnuQv to data
# Added id7orqN to data
# Added IE3F3qv to data
# Added iebf1dP to data
# Added IEDLsgI to data
# Added ieQjLxI to data
# Added Igaj1C8 to data
# Added igKzKhD to data
# Added Ih7bGXD to data
# Added IH7E1jD to data
# Added iH7vh0I to data
# Added iHkycAH to data
# Added IHwuZCE to data
# Added iig2y6T to data
# Added IjktBtd to data
# Added iJUm7hE to data
# Added ilAtJvH to data
# Added IlgFe7P to data
# Added iLhLB1l to data
# Added ImDaj6H to data
# Added InD8kOa to data
# Added Ip5sfpZ to data
# Added iRFs6TI to data
# Added iRoxRKJ to data
# Added IsESVfZ to data
# Added iT4y9Wp to data
# Added ItuoAae to data
# Added itzLvAS to data
# Added IUzvX7x to data
# Added Ix1vIeR to data
# Added Ixf1COH to data
# Added iXS3Wvx to data
# Added IyNtYf1 to data
# Added Iz8T8rm to data
# Added j0NDRvg to data
# Added J1oFmvC to data
# Added j24hoZk to data
# Added J2kP6ea to data
# Added j5szfT6 to data
# Added j6m6nlD to data
# Added J7zl1FC to data
# Added j9UbZTA to data
# Added JBN019E to data
# Added jbzeBfN to data
# Added jcBYcdB to data
# Added JdDyEJK to data
# Added jEkw72f to data
# Added JfEzLDK to data
# Added jFZk26O to data
# Added jg2zjVE to data
# Added jjHPwwo to data
# Added jJKruas to data
# Added jjo6Q3i to data
# Added JkyErAZ to data
# Added jLkIPaI to data
# Added jLomhBW to data
# Added jMPfhT7 to data
# Added jMpoNGn to data
# Added jN0nr8S to data
# Added JoBSaQH to data
# Added JoE1Agc to data
# Added jQ6JBF7 to data
# Added JtQS4bB to data
# Added jTtqtZF to data
# Added jtTzo1J to data
# Added jUCFqJn to data
# Added jv3bKx4 to data
# Added jvEW6ZT to data
# Added JwmlExm to data
# Added JxEQT1E to data
# Added jxzvszG to data
# Added k1MLjvK to data
# Added K2Dtuug to data
# Added K2yQMmC to data
# Added K3W71pl to data
# Added K5lJigV to data
# Added k87HT7g to data
# Added K8oak1H to data
# Added k96CNsX to data
# Added kAjEBVE to data
# Added KDF3WYm to data
# Added KDLl7ec to data
# Added kEbIGah to data
# Added kEXRMSs to data
# Added KFkpQRi to data
# Added KgnY5Ln to data
# Added kHlJN8C to data
# Added KiI9pBz to data
# Added KIILcev to data
# Added kIYrrA5 to data
# Added kkAUnwK to data
# Added KKvmnRI to data
# Added kKy0T2e to data
# Added KkzCJlv to data
# Added KpcrNUP to data
# Added KqcJZNp to data
# Added KqJb64B to data
# Added kR9TSCd to data
# Added krA7v7X to data
# Added ks6vQ6j to data
# Added ksYDKpv to data
# Added KUERrKo to data
# Added kUM9VQV to data
# Added KUyUKaP to data
# Added KXFWQSs to data
# Added KxsJjoa to data
# Added kynNGLW to data
# Added KYvbwkf to data
# Added kZjTuZ7 to data
# Added L09mpsw to data
# Added l0gaR9Q to data
# Added l0tkw1S to data
# Added L1FVZli to data
# Added l1WWuiL to data
# Added L3fTKP0 to data
# Added L4kEVC1 to data
# Added L4SHOws to data
# Added l52w4nh to data
# Added l8JyH5t to data
# Added lc9vall to data
# Added ldbEA7L to data
# Added LEqsMZh to data
# Added lgkSsRu to data
# Added lgrTEZY to data
# Added lhMut91 to data
# Added LICfmmD to data
# Added LIfsgd0 to data
# Added LIYsnd9 to data
# Added lJsFzzu to data
# Added LKcjPQP to data
# Added lKI08oo to data
# Added LlogRqt to data
# Added lMTapak to data
# Added lNJN8GF to data
# Added lnmhtat to data
# Added lo6ulbq to data
# Added lOSOnMf to data
# Added lOXWIFy to data
# Added lPkWuLx to data
# Added lQLS7D3 to data
# Added lRfWZhq to data
# Added LrJjc51 to data
# Added lrl1RcK to data
# Added LrviO2W to data
# Added lt7F2VS to data
# Added LtESj6P to data
# Added ltK88c8 to data
# Added lup5j7e to data
# Added lXhpTez to data
# Added lXMgqGz to data
# Added lYHKVvv to data
# Added lZDob9u to data
# Added LZlOvQf to data
# Added lzYUNyR to data
# Added m0fMo3h to data
# Added M5wCRYC to data
# Added m6snJkC to data
# Added M84wgir to data
# Added m8LhYmU to data
# Added MCCJyls to data
# Added McoTY6Z to data
# Added meSnAHk to data
# Added mFV4XG7 to data
# Added mh6fCBB to data
# Added mhIsKzJ to data
# Added mHNXIrk to data
# Added MjcPdIc to data
# Added mkwFDsB to data
# Added MLZiODp to data
# Added mOgk2CE to data
# Added mpNludO to data
# Added ms1OzuL to data
# Added msIscji to data
# Added MSnfyMO to data
# Added mtIznur to data
# Added MUhRqTQ to data
# Added mUqRQMR to data
# Added MwjYSX3 to data
# Added mz99BRR to data
# Added n0Golr5 to data
# Added N2TPFvC to data
# Added n3brw6Y to data
# Added n3lnU0W to data
# Added N3zGyGJ to data
# Added nAnhIsx to data
# Added naqu5wb to data
# Added nauWbVx to data
# Added nAwtD2o to data
# Added NBxDmM6 to data
# Added nCvTZ4a to data
# Added nDFLQpC to data
# Added nDrmDsD to data
# Added nebzew3 to data
# Added NGBaXdN to data
# Added NI6L3r4 to data
# Added Niamb8h to data
# Added nIZk3TZ to data
# Added nKdcueP to data
# Added NkzXPaf to data
# Added Nlh9kcN to data
# Added nmKN5Wn to data
# Added NmWLg9Q to data
# Added nNRp4ua to data
# Added NOHwDq7 to data
# Added Np3q9qV to data
# Added NqH6HER to data
# Added nR1jJeW to data
# Added NR8WHvD to data
# Added NRFJr74 to data
# Added NRVHZpQ to data
# Added NRXO89q to data
# Added nTQ8OLx to data
# Added NX4kw8u to data
# Added ny4eSMY to data
# Added nycnoXe to data
# Added nzAKHe2 to data
# Added nZLjIuj to data
# Added nzqJ69n to data
# Added NZrWuib to data
# Added O29Wi6Q to data
# Added O3DxgGn to data
# Added o7Ut5Po to data
# Added o8GtnrL to data
# Added Oak4Wuk to data
# Added obX5FCw to data
# Added oC6dEB6 to data
# Added OFE2yQv to data
# Added ogXjjIN to data
# Added OHfL6Bq to data
# Added Oic7kXP to data
# Added OJwBKjt to data
# Added okvGJu6 to data
# Added OL7KHgS to data
# Added oLdtCgC to data
# Added OLSvdGd to data
# Added oNG7uBt to data
# Added OoDy3iV to data
# Added ooPmUsX to data
# Added op2DSWA to data
# Added opFoa3z to data
# Added osBk7u3 to data
# Added OSkmnEL to data
# Added OUGncYs to data
# Added Ov6EWUy to data
# Added oVkJSHl to data
# Added OwCGyjL to data
# Added OWw1Fbp to data
# Added OxcapRU to data
# Added oXciBkE.jpg to data
# Added oXmMWxM to data
# Added oYbs0bA to data
# Added ozItDy2 to data
# Added OZr3Wg7 to data
# Added p2IeD7Q to data
# Added p2sGbOF to data
# Added p4dh3wd to data
# Added P4gas0k to data
# Added p7pDmyD to data
# Added P9AzcSD to data
# Added PBY12zq to data
# Added pccqm0o to data
# Added PCOnGhE to data
# Added pDmn3do to data
# Added PeaZ8Uz to data
# Added PejJTfA to data
# Added PGSffxT to data
# Added PijaCnT to data
# Added PKiKHmF to data
# Added pks2oKf to data
# Added plhwoWB to data
# Added pLXcWrF to data
# Added pMX6PpQ to data
# Added PN0wkXN to data
# Added PNkK4rc to data
# Added poMkU9P to data
# Added Pp3KosU to data
# Added pPcy7EG to data
# Added PqWv3bV to data
# Added PRcbyMZ to data
# Added pRnVnA0 to data
# Added ps3WTw2 to data
# Added PsaDoK2 to data
# Added PsqQDvF to data
# Added ptkWIBs to data
# Added pWjBqtM to data
# Added px4k8NB to data
# Added pY4sAj1 to data
# Added pyJkvD3 to data
# Added pZG4mkA to data
# Added pzSEtJW to data
# Added q10sVyP to data
# Added q3r7gBv to data
# Added q4jYswh to data
# Added Q4OX3rx to data
# Added Q7FZbTQ to data
# Added q86LqAn to data
# Added q9QjnjS to data
# Added QAJadC8 to data
# Added QcHBtRL to data
# Added QcLd0o2 to data
# Added qCPubek to data
# Added qcqURpM to data
# Added QEZbysr to data
# Added qF0alAC to data
# Added QFdW3gX to data
# Added QfmBTTP to data
# Added QfSBaHm to data
# Added qgDl4ez to data
# Added QGqw36U to data
# Added QHFyzqX to data
# Added QHrv83h.jpg to data
# Added qibqzyC.jpg to data
# Added QIJeREW to data
# Added qIN7crd to data
# Added qJOqDGH to data
# Added QKdvL4u to data
# Added qNY7FjO to data
# Added Qo7nA66 to data
# Added QP92meb to data
# Added Qp98ZFM to data
# Added qPPM8oI to data
# Added qPWszsZ to data
# Added qq2Z7Qt to data
# Added QqAkS98 to data
# Added qr0Uwei to data
# Added Qrh3S5l to data
# Added qrM98Y3 to data
# Added QrQCyan to data
# Added QsGDLWt to data
# Added qSRcxAq to data
# Added QT9JWIP to data
# Added qtsFqha to data
# Added qUJJXrh to data
# Added qVQhBNz to data
# Added qwlIhPB to data
# Added qwxnmA7 to data
# Added qxdZwEy to data
# Added QxrWyJC to data
# Added Qyt4p3a to data
# Added r00Vw8D to data
# Added r1rg5Fe to data
# Added R2m8gNb to data
# Added r5etZhb to data
# Added raH2b0Q to data
# Added RAnXGo7 to data
# Added RaVdLYj to data
# Added rCZ7EZd to data
# Added RD7UcRu to data
# Added RD8SUXG to data
# Added rdYVwMR to data
# Added RdzWRon to data
# Added rIefPs6 to data
# Added RIQGQXX to data
# Added riQppt7 to data
# Added rmNBpDN to data
# Added RPWhxYE to data
# Added RQVCGK9 to data
# Added rrFjTsb to data
# Added RscDlXT to data
# Added rt9AYdV to data
# Added RT9NV1G to data
# Added rtillcx to data
# Added ruzypN9 to data
# Added RxHbIgC to data
# Added rXvoQFP to data
# Added rZ6HJRP to data
# Added RzdmqQS to data
# Added S0rYgiI to data
# Added s146H9K to data
# Added S1UjdB9 to data
# Added S3UPwFl to data
# Added S3VC0lz to data
# Added s5f7m4U to data
# Added S7HcJGa to data
# Added S9jgYmv to data
# Added sb7QVcg to data
# Added SbSaP0x to data
# Added ScqmhGY to data
# Added ScVSoSE to data
# Added SD1oHPF to data
# Added Se8xX70 to data
# Added sespHpk to data
# Added seT09LJ to data
# Added sFlLzEC to data
# Added SFWOkNb to data
# Added SG5ALcr to data
# Added sg962mx to data
# Added sgx8UQG to data
# Added ShB4M1W to data
# Added SI7lTfU to data
# Added sirbau0 to data
# Added SjooePr to data
# Added sl8xmaC to data
# Added smCg4NS to data
# Added SMnWDXo to data
# Added SmUEv2b to data
# Added sN3uLAN to data
# Added SPIzKeX to data
# Added sPR6l8F to data
# Added SQzuLuN to data
# Added srIrpGz to data
# Added STHrei0 to data
# Added sTqTww0 to data
# Added stX9cOU to data
# Added SvUfDEk to data
# Added Sy7WiHw to data
# Added sYnRwNW to data
# Added T06Bnfc to data
# Added t0ZpUOG to data
# Added t1phDE7 to data
# Added t4nwPBp to data
# Added T4Y1mE9 to data
# Added T6KAJVK to data
# Added TAjE759 to data
# Added TAO4VuO to data
# Added tB1Btyf to data
# Added TbfpI23 to data
# Added tcqFfON to data
# Added tCqZSes to data
# Added tEFg4vp to data
# Added thCeQJ1 to data
# Added tHySU1B to data
# Added ti7RjeA to data
# Added TISs0cM to data
# Added TJD2Oem to data
# Added TJzrbSJ to data
# Added TkbBYwW to data
# Added Tm4WRpM to data
# Added TmoIia6 to data
# Added tnKdKAe to data
# Added tOVTiOS to data
# Added Tq5m7OH to data
# Added tQ7rx3T to data
# Added TRKY1eS to data
# Added tS7HWRx to data
# Added tskKg80 to data
# Added TtWDD95 to data
# Added TTwZvc6 to data
# Added tvI2aOC to data
# Added tvrtY1r to data
# Added twAUB0s to data
# Added TWQaiNS to data
# Added TX3gyhM to data
# Added TYWSX2w to data
# Added tz2l60r to data
# Added tzUJSTU to data
# Added u6L5sPa to data
# Added u77xFCn to data
# Added u7HBr8R to data
# Added U9b6UuM to data
# Added UA50EIa to data
# Added uAGPRSO to data
# Added UBjiNLG to data
# Added ucGpSvP to data
# Added Ue8SNiR to data
# Added UeNYrZL to data
# Added uhEAVtx to data
# Added UKsQdHE to data
# Added UKZYpPW to data
# Added UmE1t2r to data
# Added UmnlQPP to data
# Added uOX4DmV to data
# Added uPLVdCK to data
# Added uql41aX to data
# Added UqVcGxN to data
# Added uSCDael to data
# Added usgQAER to data
# Added USMA4Wu to data
# Added UsmpcgR to data
# Added USrkMXV to data
# Added utCzG9n to data
# Added UVFz48E to data
# Added UwxV6eR to data
# Added Uxw0NFx to data
# Added uy8NSrQ to data
# Added uY99BgU to data
# Added uZ7BbNj to data
# Added uztdKHL to data
# Added V0nePqI to data
# Added V8YmQuB to data
# Added V9363tR to data
# Added va3zoqd to data
# Added vanHpf3 to data
# Added vb3j8XG to data
# Added vbNoxv8 to data
# Added VckX1h3 to data
# Added VdeipTu to data
# Added Vdz5lpQ to data
# Added Vfvowdt to data
# Added VgjaFns to data
# Added vGrPZ67 to data
# Added vgWTQUM to data
# Added VHuotjM to data
# Added VHwYmyE to data
# Added vJJf2ss to data
# Added vKkjXSS to data
# Added VKm1V5Q to data
# Added vkMBNOD to data
# Added vkPraI6 to data
# Added vmmTPsf to data
# Added vnH5P2N to data
# Added Vp1iZzB to data
# Added vpkvL4B to data
# Added Vq6mfzF to data
# Added vrov6MF to data
# Added Vsl278G to data
# Added Vt1brGw to data
# Added vXtj0nS to data
# Added vYAIsLr to data
# Added vYK3cAV to data
# Added VZadqAQ to data
# Added VZvcGXa to data
# Added W3RIsYM to data
# Added W5R1xca to data
# Added w6sU8I9 to data
# Added w92P4KB to data
# Added wcPIN1Z to data
# Added WffXuoE to data
# Added WHYYgcl to data
# Added wmqnRhd to data
# Added WNXG0ZO to data
# Added wohVf88 to data
# Added wot19Fo to data
# Added WpKd13Z to data
# Added wPQ7zko to data
# Added WqFyzwd to data
# Added wQOksAF to data
# Added Wrdx1lI to data
# Added WrhabQs to data
# Added WRjKRVZ to data
# Added WRlghNg to data
# Added wSLg9Oc to data
# Added WtBbHrs to data
# Added WUNLuuJ to data
# Added wUOp2LE to data
# Added WVZgSOP to data
# Added wznDxS1 to data
# Added x4b0Mie to data
# Added x4W4nqZ to data
# Added X7vgqKH to data
# Added X7yXFeI to data
# Added X8W8AWF to data
# Added xavf8S6 to data
# Added xCFn4RS to data
# Added XDdEtXs to data
# Added XFdQk1A to data
# Added xFL9T3A to data
# Added xh5IK0d to data
# Added XHQjZ7E to data
# Added XJwGFsz to data
# Added xKDpyVm to data
# Added xLPdYmD to data
# Added xnx1SKn to data
# Added xOcyrHZ to data
# Added Xpe3EHq to data
# Added xPFc1wk to data
# Added xPXybrF to data
# Added XUXsQSE to data
# Added xVq3rFv to data
# Added xXLfKuY to data
# Added xYUsDft to data
# Added Y26ITFN to data
# Added Y4AwcLn to data
# Added y4iGsk2 to data
# Added y5xytZh to data
# Added Y7HMg7o to data
# Added Y8epa7v to data
# Added Ya9hXvB to data
# Added YACxtO8 to data
# Added yaf50zs to data
# Added YaUOfvz to data
# Added yBqfFVS to data
# Added yCM8Fw3 to data
# Added yCVW0lO to data
# Added yE0crjF to data
# Added yFq73CI to data
# Added Yh4bdek to data
# Added YIZoQIM to data
# Added Yl01xdg to data
# Added YlKR5nE to data
# Added yLriFPv to data
# Added YNLOk6O to data
# Added Yo8EKmn to data
# Added YpHHwrc to data
# Added YPj0PiM to data
# Added yPKg0XW to data
# Added YPRG7P3 to data
# Added ypv2Ps2 to data
# Added yr6Zyf0 to data
# Added yty9V0v to data
# Added YU5KdHa to data
# Added Yw0b3g5 to data
# Added yw3YEuC to data
# Added YwsXsbA to data
# Added yWzMrh6 to data
# Added yXcfTfN to data
# Added YYzpHPG to data
# Added yZr3NjJ to data
# Added z1SSoXS to data
# Added z2hS8zE to data
# Added z4vIXvU to data
# Added Z5FK37y to data
# Added Z8Fh99q to data
# Added ZbScvk0 to data
# Added zBxedwt to data
# Added zCAwmrE to data
# Added zCQhRyk to data
# Added zE0gIS4 to data
# Added ZeNojoH to data
# Added zFAasJX to data
# Added ZFsEUYk to data
# Added ZgHJ9wg to data
# Added ZgXGRsv to data
# Added zgZI38g to data
# Added ZH8dqt3 to data
# Added zhDHfEx to data
# Added zHfkTHT to data
# Added ZHHl7pp to data
# Added ZjxYM3D to data
# Added zl8H9r2 to data
# Added ZLa6T9x to data
# Added zlBPg6k to data
# Added ZLpX8sE to data
# Added zlQbQ4J to data
# Added ZLukqxu.jpg to data
# Added ZNDnZoE to data
# Added ZNeBY3J to data
# Added zPAiWQX to data
# Added ZpFiSsx to data
# Added zpskyDb to data
# Added zq7JmcP to data
# Added zR5TljC to data
# Added zrkNuxY to data
# Added zrutdh5 to data
# Added zTYZkN1 to data
# Added Zv8xTJf to data
# Added zvxGqQX to data
# Added zwAJB5O to data
# Added zYl7M6S to data

# %%
# Update cards.json with new images
with open('./cards.json') as file:
    data = load(file)
existing = {card['filename'] for card in data}
for i, image in enumerate(listdir('./upscaled/'), 1):
    fname = image.replace('.png', '')
    if fname not in existing:
        data.append({"id": i, "name": "", "guild": "", "class": "", "race": "", "level": 3, "rarity": "", "strength": "", 'filename': fname})
with open('./cards.json', 'w') as file:
    dump(data, file, indent=4)
# Out:
# Added description for 3Y5poMg to data
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 9
#       7 for card in data:
#       8     image = cv2.imread('./upscaled/' + card['filename'] + '.png')
# ----> 9     text = pytesseract.image_to_string(image, lang ='eng')
#      10     # create and write in description field
#      11     card['description'] = text
#
# File d:\Documents\GitHub\eredan-arena-database\.venv\Lib\site-packages\pytesseract\pytesseract.py:486, in image_to_string(image, lang, config, nice, output_type, timeout)
#     481 """
#     482 Returns the result of a Tesseract OCR run on the provided image to string
#     483 """
#     484 args = [image, 'txt', lang, config, nice, timeout]
# --> 486 return {
#     487     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488     Output.DICT: lambda: {'text': run_and_get_output(*args)},
#     489     Output.STRING: lambda: run_and_get_output(*args),
#     490 }[output_type]()
#
# File d:\Documents\GitHub\eredan-arena-database\.venv\Lib\site-packages\pytesseract\pytesseract.py:489, in image_to_string.<locals>.<lambda>()
#     481 """
#     482 Returns the result of a Tesseract OCR run on the provided image to string
#     483 """
#     484 args = [image, 'txt', lang, config, nice, timeout]
#     486 return {
#     487     Output.BYTES: lambda: run_and_get_output(*(args + [True])),
#     488     Output.DICT: lambda: {'text': run_and_get_output(*args)},
# --> 489     Output.STRING: lambda: run_and_get_output(*args),
#     490 }[output_type]()
#
# File d:\Documents\GitHub\eredan-arena-database\.venv\Lib\site-packages\pytesseract\pytesseract.py:341, in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     332 def run_and_get_output(
#     333     image,
#     334     extension='',
#    (...)    339     return_bytes=False,
#     340 ):
# --> 341     with save(image) as (temp_name, input_filename):
#     342         kwargs = {
#     343             'input_filename': input_filename,
#     344             'output_filename_base': temp_name,
#    (...)    349             'timeout': timeout,
#     350         }
#     352         run_tesseract(**kwargs)
#
# File C:\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File d:\Documents\GitHub\eredan-arena-database\.venv\Lib\site-packages\pytesseract\pytesseract.py:214, in save(image)
#     212     yield f.name, realpath(normpath(normcase(image)))
#     213     return
# --> 214 image, extension = prepare(image)
#     215 input_file_name = f'{f.name}_input{extsep}{extension}'
#     216 image.save(input_file_name, format=image.format)
#
# File d:\Documents\GitHub\eredan-arena-database\.venv\Lib\site-packages\pytesseract\pytesseract.py:191, in prepare(image)
#     188     image = Image.fromarray(image)
#     190 if not isinstance(image, Image.Image):
# --> 191     raise TypeError('Unsupported image object')
#     193 extension = 'PNG' if not image.format else image.format
#     194 if extension not in SUPPORTED_FORMATS:
#
# TypeError: Unsupported image object

# %%
# Update guilds
def update_cards_with_guilds(json_path, urls_dir):
    with open(json_path) as file:
        data = load(file)
    filename_map = {c['filename']: c for c in data}
    for txt_file in Path(urls_dir).glob("*.txt"):
        folder = txt_file.stem
        with txt_file.open() as file:
            for line in file:
                card = filename_map.get(line.strip())
                if card: card['guild'] = folder
    with open(json_path, 'w') as file:
        dump(data, file, indent=4)
update_cards_with_guilds('./cards.json', './docs/urls/')
